# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

from bs4 import BeautifulSoup
import requests
import pandas as pd
import src
from src import object_test
from src import open_page as op

import psycopg2
from sqlalchemy import create_engine

from src import local

# %%
engine = create_engine('postgresql://postgres:abc@127.0.0.1:5432/ufc_odds')


strikes = pd.read_sql_table('strikes', engine)
general = pd.read_sql_table('general', engine)

# %%
len(strikes.bout_id.unique())
# Out:
# 5622

# %%
strikes.to_csv('../data/strikes.csv')
general.to_csv('../data/general.csv')

# %%
general
# Out:
#                                                  fighter  \
# 0      Dustin Poirier Dan Hooker                     ...
# 1      Dustin Poirier Dan Hooker                     ...
# 2      Dustin Poirier Dan Hooker                     ...
# 3      Dustin Poirier Dan Hooker                     ...
# 4      Dustin Poirier Dan Hooker                     ...
# ...                                                  ...
# 12967  Gerard Gordeau Kevin Rosier                   ...
# 12968  Ken Shamrock Patrick Smith                    ...
# 12969  Royce Gracie Art Jimmerson                    ...
# 12970  Kevin Rosier Zane Frazier                     ...
# 12971  Gerard Gordeau Teila Tuli                     ...
#
#                                                       kd  \
# 0      0  0                                          ...
# 1      0  0                                          ...
# 2      0  0                                          ...
# ...

# %%
pd.DataFrame().to_sql()
