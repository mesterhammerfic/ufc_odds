# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from src import object_test

# %% [markdown]
# # 1. Event Search

# %%
search_page = object_test.open_tapology_link('/search?term=ufc&mainSearchFilter=events')

# %%
events = object_test.events()

# %%
events.table
# Out:
# Empty DataFrame
# Columns: [event, name, date, bouts, link, location, venue, enclosure, start_time]
# Index: []

# %%
events.create_events_df(search_page)

# %%
events.table
# Out:
#      bouts       date  enclosure            event  index  \
# 0       12 2020-06-20        NaN  UFC Fight Night     22
# 1       10 2020-06-13        NaN  UFC Fight Night     23
# 2       12 2020-06-06        NaN          UFC 250     24
# 3       11 2020-05-30        NaN  UFC Fight Night     25
# 4       11 2020-05-16        NaN  UFC Fight Night     26
# ..     ...        ...        ...              ...    ...
# 498     10 1995-04-07        NaN            UFC 5    864
# 499     10 1994-12-16        NaN            UFC 4    865
# 500      6 1994-09-09        NaN            UFC 3    866
# 501     15 1994-03-11        NaN            UFC 2    867
# 502      8 1993-11-12        NaN            UFC 1    868
#
#                                                   link  location  \
# 0                /fightcenter/events/67608-ufc-on-espn       NaN
# 1                /fightcenter/events/67562-ufc-on-espn       NaN
# 2                    /fightcenter/events/67364-ufc-251       NaN
# 3            /fightcenter/events/69127-ufc-fight-night       NaN
# 4             /fightcenter/events/67412-ufc-on-espn-33       NaN
# ..                                                 ...       ...
# 498      /fightcenter/events/ufc-5-return-of-the-beast       NaN
# 499  /fightcenter/events/ufc-4-revenge-of-the-warriors       NaN
# 500       /fightcenter/events/ufc-3-the-american-dream       NaN
# 501               /fightcenter/events/ufc-2-no-way-out       NaN
# 502            /fightcenter/events/ufc-1-the-beginning       NaN
#
#                         name  start_time  venue
# 0         Blaydes vs. Volkov         NaN    NaN
# 1           Eye vs. Calvillo         NaN    NaN
# 2          Nunes vs. Spencer         NaN    NaN
# 3          Woodley vs. Burns         NaN    NaN
# 4         Overeem vs. Harris         NaN    NaN
# ..                       ...         ...    ...
# 498      Return of the Beast         NaN    NaN
# 499  Revenge of the Warriors         NaN    NaN
# 500       The American Dream         NaN    NaN
# 501               No Way Out         NaN    NaN
# 502            The Beginning         NaN    NaN
#
# [503 rows x 10 columns]

# %% [markdown]
# # 2. Event Page
# - Creates bouts table
# - Adds events info

# %% [markdown]
# ## a1. Create bouts

# %%
event_link = events.table.link[0]
event_link
# Out:
# '/fightcenter/events/67608-ufc-on-espn'

# %%
event_page = object_test.open_tapology_link(event_link)
event_soup = BeautifulSoup(event_page)

bouts = object_test.bouts()

# %%
bouts

# %%
bouts.create_bouts_table(event_soup,event_link)

# %%
bouts.table
# Out:
#         bout_type                             event_link  \
# 0      Main Event  /fightcenter/events/67608-ufc-on-espn
# 1   Co-Main Event  /fightcenter/events/67608-ufc-on-espn
# 2       Main Card  /fightcenter/events/67608-ufc-on-espn
# 3       Main Card  /fightcenter/events/67608-ufc-on-espn
# 4       Main Card  /fightcenter/events/67608-ufc-on-espn
# 5          Prelim  /fightcenter/events/67608-ufc-on-espn
# 6          Prelim  /fightcenter/events/67608-ufc-on-espn
# 7          Prelim  /fightcenter/events/67608-ufc-on-espn
# 8          Prelim  /fightcenter/events/67608-ufc-on-espn
# 9          Prelim  /fightcenter/events/67608-ufc-on-espn
# 10         Prelim  /fightcenter/events/67608-ufc-on-espn
# 11         Prelim  /fightcenter/events/67608-ufc-on-espn
#
#                fighter_0          fighter_1                          length  \
# 0         Curtis Blaydes   Alexander Volkov           5 Rounds, 25:00 Total
# 1            Josh Emmett       Shane Burgos           3 Rounds, 15:00 Total
# 2      Raquel Pennington      Marion Reneau           3 Rounds, 15:00 Total
# 3         Belal Muhammad         Lyman Good           3 Rounds, 15:00 Total
# 4             Jim Miller  Roosevelt Roberts               2:25 Round 1 of 3
# 5            Bobby Green         Clay Guida           3 Rounds, 15:00 Total
# 6           Tecia Torres  Brianna Van Buren           3 Rounds, 15:00 Total
# 7   Marc-André Barriault     Oskar Piechota   4:50 Round 2 of 3, 9:50 Total
# 8      Gillian Robertson      Cortney Casey  4:32 Round 3 of 3, 14:32 Total
# 9          Justin Jaynes      Frank Camacho               0:41 Round 1 of 3
# 10         Lauren Murphy  Roxanne Modafferi           3 Rounds, 15:00 Total
# 11        Austin Hubbard       Max Rohskopf  5:00 Round 2 of 3, 10:00 Total
#
#                                                  link  \
# 0   /fightcenter/bouts/492662-ufc-on-espn-curtis-r...
# 1   /fightcenter/bouts/503003-ufc-fight-night-josh...
# 2   /fightcenter/bouts/502885-ufc-fight-night-rock...
# 3   /fightcenter/bouts/503014-ufc-fight-night-lyma...
# 4   /fightcenter/bouts/505888-ufc-fight-night-roos...
# 5   /fightcenter/bouts/505820-ufc-fight-night-clay...
# 6   /fightcenter/bouts/503193-ufc-fight-night-the-...
# 7   /fightcenter/bouts/492288-ufc-on-espn-marc-and...
# 8   /fightcenter/bouts/503141-ufc-fight-night-cort...
# 9   /fightcenter/bouts/507265-ufc-fight-night-fran...
# 10  /fightcenter/bouts/502859-ufc-fight-night-roxa...
# 11  /fightcenter/bouts/506653-ufc-fight-night-aust...
#
#                                    method order  pro_am  referee  \
# 0                     Decision, Unanimous    12     NaN      NaN
# 1                     Decision, Unanimous    11     NaN      NaN
# 2                     Decision, Unanimous    10     NaN      NaN
# 3                     Decision, Unanimous     9     NaN      NaN
# 4                      Submission, Armbar     8     NaN      NaN
# 5                     Decision, Unanimous     7     NaN      NaN
# 6                     Decision, Unanimous     6     NaN      NaN
# 7   KO/TKO, Uppercuts to Ground and Pound     5     NaN      NaN
# 8            Submission, Rear Naked Choke     4     NaN      NaN
# 9                           KO/TKO, Hooks     3     NaN      NaN
# 10                    Decision, Unanimous     2     NaN      NaN
# 11                     KO/TKO, Retirement     1     NaN      NaN
#
#    scheduled_rounds weight_class
# 0             5 x 5          265
# 1             3 x 5          145
# 2             3 x 5          135
# 3             3 x 5          170
# 4             3 x 5          160
# 5             3 x 5          155
# 6             3 x 5          115
# 7             3 x 5          185
# 8             3 x 5          125
# 9             3 x 5          155
# 10            3 x 5          125
# 11            3 x 5          155

# %% [markdown]
# ## b1. Add event info

# %%
events.update_missing_info(event_soup,event_link)

# %%
events.table
# Out:
#      bouts       date enclosure            event  index  \
# 0       12 2020-06-20   Octagon  UFC Fight Night     22
# 1       10 2020-06-13       NaN  UFC Fight Night     23
# 2       12 2020-06-06       NaN          UFC 250     24
# 3       11 2020-05-30       NaN  UFC Fight Night     25
# 4       11 2020-05-16       NaN  UFC Fight Night     26
# ..     ...        ...       ...              ...    ...
# 498     10 1995-04-07       NaN            UFC 5    864
# 499     10 1994-12-16       NaN            UFC 4    865
# 500      6 1994-09-09       NaN            UFC 3    866
# 501     15 1994-03-11       NaN            UFC 2    867
# 502      8 1993-11-12       NaN            UFC 1    868
#
#                                                   link  \
# 0                /fightcenter/events/67608-ufc-on-espn
# 1                /fightcenter/events/67562-ufc-on-espn
# 2                    /fightcenter/events/67364-ufc-251
# 3            /fightcenter/events/69127-ufc-fight-night
# 4             /fightcenter/events/67412-ufc-on-espn-33
# ..                                                 ...
# 498      /fightcenter/events/ufc-5-return-of-the-beast
# 499  /fightcenter/events/ufc-4-revenge-of-the-warriors
# 500       /fightcenter/events/ufc-3-the-american-dream
# 501               /fightcenter/events/ufc-2-no-way-out
# 502            /fightcenter/events/ufc-1-the-beginning
#
#                              location                     name  \
# 0    Las Vegas, Nevada, United States       Blaydes vs. Volkov
# 1                                 NaN         Eye vs. Calvillo
# 2                                 NaN        Nunes vs. Spencer
# 3                                 NaN        Woodley vs. Burns
# 4                                 NaN       Overeem vs. Harris
# ..                                ...                      ...
# 498                               NaN      Return of the Beast
# 499                               NaN  Revenge of the Warriors
# 500                               NaN       The American Dream
# 501                               NaN               No Way Out
# 502                               NaN            The Beginning
#
#                                             start_time     venue
# 0    \nSaturday 06.20.2020 at 05:00 PM ET\n\nU.S. B...  UFC APEX
# 1                                                  NaN       NaN
# 2                                                  NaN       NaN
# 3                                                  NaN       NaN
# 4                                                  NaN       NaN
# ..                                                 ...       ...
# 498                                                NaN       NaN
# 499                                                NaN       NaN
# 500                                                NaN       NaN
# 501                                                NaN       NaN
# 502                                                NaN       NaN
#
# [503 rows x 10 columns]

# %% [markdown]
# # 3. Bout page
# - create fighter_instances
# - add missing bouts info

# %% [markdown]
# ## a1. fighter_instances

# %%
bout_link = bouts.table.link[0]
bout_link
# Out:
# '/fightcenter/bouts/492662-ufc-on-espn-curtis-razor-blaydes-vs-alexander-drago-volkov'

# %%
bout_page = object_test.open_tapology_link(bout_link)
bout_soup = BeautifulSoup(bout_page)

# %%
fighter_instances = object_test.fighter_instances()
fighter_instances.table
# Out:
# Empty DataFrame
# Columns: [Pro Record At Fight, Record After Fight, Betting Odds, Nationality, Fighting out of, Age at Fight, Weigh-In Result, Height, Reach, Gym, fighter_link, bout_link, instance_id]
# Index: []

# %%
fighter_instances.create_fighter_instances_table(bout_page, bout_link)
fighter_instances.table
# Out:
#   Pro Record At Fight Record After Fight              Betting Odds  \
# 0              13-2-0    Climbed to 14-2  -350 (Moderate Favorite)
# 1              31-7-0       Fell to 31-8  +265 (Moderate Underdog)
#
#      Nationality    Fighting out of                Age at Fight  \
# 0  United States  Chicago, Illinois  29 years, 4 months, 2 days
# 1         Russia     Moscow, Russia  31 years, 7 months, 6 days
#
#          Weigh-In Result        Height          Reach                   Gym  \
# 0  261.0 lbs (118.4 kgs)  6'4" (193cm)  80.0" (203cm)  Elevation Fight Team
# 1  247.0 lbs (112.0 kgs)  6'7" (201cm)  81.0" (206cm)           Strela Team
#
#                                  fighter_link  \
# 0  /fightcenter/fighters/51080-curtis-blaydes
# 1      /fightcenter/fighters/alexander-volkov
#
#                                            bout_link  \
# 0  /fightcenter/bouts/492662-ufc-on-espn-curtis-r...
# 1  /fightcenter/bouts/492662-ufc-on-espn-curtis-r...
#
#                                          instance_id
# 0  /fightcenter/bouts/492662-ufc-on-espn-curtis-r...
# 1  /fightcenter/bouts/492662-ufc-on-espn-curtis-r...

# %% [markdown]
# ## b1. add missing bouts info

# %%
bouts.update_missing_info(bout_soup, bout_link)
bouts.table
# Out:
#         bout_type                             event_link  \
# 0      Main Event  /fightcenter/events/67608-ufc-on-espn
# 1   Co-Main Event  /fightcenter/events/67608-ufc-on-espn
# 2       Main Card  /fightcenter/events/67608-ufc-on-espn
# 3       Main Card  /fightcenter/events/67608-ufc-on-espn
# 4       Main Card  /fightcenter/events/67608-ufc-on-espn
# 5          Prelim  /fightcenter/events/67608-ufc-on-espn
# 6          Prelim  /fightcenter/events/67608-ufc-on-espn
# 7          Prelim  /fightcenter/events/67608-ufc-on-espn
# 8          Prelim  /fightcenter/events/67608-ufc-on-espn
# 9          Prelim  /fightcenter/events/67608-ufc-on-espn
# 10         Prelim  /fightcenter/events/67608-ufc-on-espn
# 11         Prelim  /fightcenter/events/67608-ufc-on-espn
#
#                fighter_0          fighter_1                          length  \
# 0         Curtis Blaydes   Alexander Volkov           5 Rounds, 25:00 Total
# 1            Josh Emmett       Shane Burgos           3 Rounds, 15:00 Total
# 2      Raquel Pennington      Marion Reneau           3 Rounds, 15:00 Total
# 3         Belal Muhammad         Lyman Good           3 Rounds, 15:00 Total
# 4             Jim Miller  Roosevelt Roberts               2:25 Round 1 of 3
# 5            Bobby Green         Clay Guida           3 Rounds, 15:00 Total
# 6           Tecia Torres  Brianna Van Buren           3 Rounds, 15:00 Total
# 7   Marc-André Barriault     Oskar Piechota   4:50 Round 2 of 3, 9:50 Total
# 8      Gillian Robertson      Cortney Casey  4:32 Round 3 of 3, 14:32 Total
# 9          Justin Jaynes      Frank Camacho               0:41 Round 1 of 3
# 10         Lauren Murphy  Roxanne Modafferi           3 Rounds, 15:00 Total
# 11        Austin Hubbard       Max Rohskopf  5:00 Round 2 of 3, 10:00 Total
#
#                                                  link  \
# 0   /fightcenter/bouts/492662-ufc-on-espn-curtis-r...
# 1   /fightcenter/bouts/503003-ufc-fight-night-josh...
# 2   /fightcenter/bouts/502885-ufc-fight-night-rock...
# 3   /fightcenter/bouts/503014-ufc-fight-night-lyma...
# 4   /fightcenter/bouts/505888-ufc-fight-night-roos...
# 5   /fightcenter/bouts/505820-ufc-fight-night-clay...
# 6   /fightcenter/bouts/503193-ufc-fight-night-the-...
# 7   /fightcenter/bouts/492288-ufc-on-espn-marc-and...
# 8   /fightcenter/bouts/503141-ufc-fight-night-cort...
# 9   /fightcenter/bouts/507265-ufc-fight-night-fran...
# 10  /fightcenter/bouts/502859-ufc-fight-night-roxa...
# 11  /fightcenter/bouts/506653-ufc-fight-night-aust...
#
#                                    method order        pro_am    referee  \
# 0                     Decision, Unanimous    12  Professional  Herb Dean
# 1                     Decision, Unanimous    11           NaN        NaN
# 2                     Decision, Unanimous    10           NaN        NaN
# 3                     Decision, Unanimous     9           NaN        NaN
# 4                      Submission, Armbar     8           NaN        NaN
# 5                     Decision, Unanimous     7           NaN        NaN
# 6                     Decision, Unanimous     6           NaN        NaN
# 7   KO/TKO, Uppercuts to Ground and Pound     5           NaN        NaN
# 8            Submission, Rear Naked Choke     4           NaN        NaN
# 9                           KO/TKO, Hooks     3           NaN        NaN
# 10                    Decision, Unanimous     2           NaN        NaN
# 11                     KO/TKO, Retirement     1           NaN        NaN
#
#    scheduled_rounds weight_class
# 0             5 x 5          265
# 1             3 x 5          145
# 2             3 x 5          135
# 3             3 x 5          170
# 4             3 x 5          160
# 5             3 x 5          155
# 6             3 x 5          115
# 7             3 x 5          185
# 8             3 x 5          125
# 9             3 x 5          155
# 10            3 x 5          125
# 11            3 x 5          155

# %% [markdown]
# # Fighter page

# %%
fighter_link = fighter_instances.table.fighter_link[0]

# %%
fighter_page = object_test.open_tapology_link(fighter_link)
fighter_soup = BeautifulSoup(fighter_page)

# %%
fighter_link
# Out:
# '/fightcenter/fighters/51080-curtis-blaydes'

# %%
fighters = object_test.fighters()
fighters.table
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
fighters.create_fighters_table(fighter_soup, fighter_link)

fighters.table
# Out:
#   header                  ProMMARecord Nickname CurrentStreak Age DateofBirth  \
# 0   Name  14-2-0, 1 NC (Win-Loss-Draw)    Razor        4 Wins  29  1991.02.18
#
#                 LastFight  WeightClass LastWeigh-In           Affiliation  \
# 0  June 20, 2020\nin\nUFC  Heavyweight    261.0 lbs  Elevation Fight Team
#
#          Height          Reach CareerDisclosedEarnings                  Born  \
# 0  6'4" (193cm)  80.0" (203cm)            $338,000 USD  Naperville, Illinois
#
#        Fightingoutof         College FoundationStyle FighterLinks  \
# 0  Chicago, Illinois  Harper College       Wrestling
#
#   PersonalLinks                                        link
# 0                /fightcenter/fighters/51080-curtis-blaydes
