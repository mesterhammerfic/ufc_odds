# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
from bs4 import BeautifulSoup
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)


from src import object_test
from src import open_page as op
from src import local
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
engine = create_engine(f'postgresql://{local.user}:{local.password}@{local.host}:{local.port}/ufc_odds')

bouts = pd.read_sql("""
                    SELECT * FROM general;
                    """,
                    engine
                   )

# %%
bouts
# Out:
#               fighter  kd    sig_str sig_str_prcnt  total_str td_count  \
# 0      Dustin Poirier   0   20 of 31           64%   20 of 31   0 of 0
# 1      Dustin Poirier   0   48 of 83           57%   53 of 88   0 of 6
# 2      Dustin Poirier   0   28 of 40           70%   38 of 50   0 of 0
# 3      Dustin Poirier   0   20 of 28           71%   43 of 53   1 of 1
# 4      Dustin Poirier   0   37 of 49           75%   54 of 67   0 of 0
# ...               ...  ..        ...           ...        ...      ...
# 25987   Art Jimmerson   0     0 of 0            0%     0 of 0   0 of 0
# 25988    Kevin Rosier   2   15 of 27           55%   38 of 53   0 of 0
# 25989    Zane Frazier   0   12 of 28           42%   13 of 29   0 of 0
# 25990  Gerard Gordeau   0     3 of 5           60%     3 of 5   0 of 0
# 25991      Teila Tuli   0     0 of 1            0%     0 of 1   0 of 1
#
#       td_prcnt sub_att pass rev  round           bout_id outcome
# 0           0%       0    0   0      1  f8dd1e75978a3957       W
# 1           0%       0    0   0      2  f8dd1e75978a3957       W
# 2           0%       1    0   0      3  f8dd1e75978a3957       W
# 3         100%       3    1   0      4  f8dd1e75978a3957       W
# 4           0%       0    0   0      5  f8dd1e75978a3957       W
# ...        ...     ...  ...  ..    ...               ...     ...
# 25987       0%       0    0   0      1  cecdc0da584274b9       L
# 25988       0%       0    0   0      1  2d2bbc86e941e05c       W
# 25989       0%       0    0   0      1  2d2bbc86e941e05c       L
# 25990       0%       0    0   0      1  567a09fd200cfa05       W
# 25991       0%       0    0   0      1  567a09fd200cfa05       L
#
# [25992 rows x 13 columns]
